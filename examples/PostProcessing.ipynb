# %% [markdown]
# # pybalmorel for Post-Processing
# This notebook provide examples on how to use pybalmorel for pre-processing, post-processing and for executing Balmorel scenarios. Check the following pages:
# - [Home](../README.md)
# - [Pre-Processing](PreProcessing.ipynb)
# - [Execution](Execution.ipynb)

# %%
### 0.1 Use development scripts or the package installed from pip
use_development = True
if use_development:
    import sys
    import os
    # Adjust the sys.path to include the project root directory
    project_root = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..'))
    if project_root not in sys.path:
        sys.path.insert(0, project_root)
    from src.pybalmorel import MainResults
    from src.pybalmorel.utils import symbol_to_df
else:
    from pybalmorel import MainResults
    from pybalmorel.utils import symbol_to_df

# %% [markdown]
# ## Working with Outputs
#
# This section presents examples of how to work with the outputs from Balmorel

# %% [markdown]
# ### MainResults
#
# The main output from Balmorel is MainResults.gdx, which may be loaded from one path (demanding different filenames, e.g., MainResults_SC1.gdx, MainResults_SC2.gdx, etc.) or several paths (which by default gives scenario names of SC1, SC2, ..., SCN format if no list of scenario_names are provided)

# %%
### 1.1.1 Loading one scenario
res = MainResults(files='MainResults_Example1.gdx', paths='files')

# Getting a result in DataFrame format
res.get_result('PRO_YCRAGF')
# Out:
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_Example1.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\classes.py:102: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = gams.GamsWorkspace()
#      Scenario  Year  Country Region                         Area  \
# 0    Example1  2030  DENMARK    DK1                    DK1_Large
# 1    Example1  2030  DENMARK    DK1                    DK1_Large
# 2    Example1  2030  DENMARK    DK1                    DK1_Large
# 3    Example1  2030  DENMARK    DK1                    DK1_Large
# 4    Example1  2030  DENMARK    DK1                    DK1_Large
# ..        ...   ...      ...    ...                          ...
# 247  Example1  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG1
# 248  Example1  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG2
# 249  Example1  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG2
# 250  Example1  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG3
# 251  Example1  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG3
#
#                                  Generation       Fuel    Commodity  \
# 0     GNR_BO_MSW_E-106_LS-35-MW-FEED_Y-2030  MUNIWASTE         HEAT
# 1                      GNR_ENG_BGAS_BP_E-36     BIOGAS         HEAT
# 2                      GNR_ENG_BGAS_BP_E-36     BIOGAS  ELECTRICITY
# 3                      GNR_ENG_BGAS_BP_E-39     BIOGAS         HEAT
# 4                      GNR_ENG_BGAS_BP_E-39     BIOGAS  ELECTRICITY
# ..                                      ...        ...          ...
# 247  GNR_WT-SP277-HH100_ONS_LS_L-RG1_Y-2030       WIND  ELECTRICITY
# 248  GNR_WT-SP277-HH100_ONS_LS_L-RG2_Y-2030       WIND  ELECTRICITY
# 249  GNR_WT-SP277-HH100_ONS_LS_L-RG2_Y-2050       WIND  ELECTRICITY
# 250  GNR_WT-SP277-HH100_ONS_LS_L-RG3_Y-2030       WIND  ELECTRICITY
# 251  GNR_WT-SP277-HH100_ONS_LS_L-RG3_Y-2050       WIND  ELECTRICITY
#
#             Technology Unit         Value
# 0              BOILERS  TWh -8.797088e-17
# 1    CHP-BACK-PRESSURE  TWh  7.072683e-04
# 2    CHP-BACK-PRESSURE  TWh  5.799600e-04
# 3    CHP-BACK-PRESSURE  TWh  2.278976e-03
# 4    CHP-BACK-PRESSURE  TWh  1.868760e-03
# ..                 ...  ...           ...
# 247            WIND-ON  TWh  7.214518e-01
# 248            WIND-ON  TWh  2.082185e+00
# 249            WIND-ON  TWh  5.335354e-01
# 250            WIND-ON  TWh  2.618147e+00
# 251            WIND-ON  TWh  2.866557e-01
#
# [252 rows x 11 columns]

# %%
### 1.1.2 Loading several scenarios
res = MainResults(files=['MainResults_Example1.gdx', 'MainResults_Example2.gdx', 'MainResults_Example3.gdx'], paths='files', scenario_names=['SC1', 'SC2', 'SC3'])

res.get_result('G_CAP_YCRAF')
# Out:
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\classes.py:102: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = gams.GamsWorkspace()
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_Example1.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_Example2.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_Example3.gdx
#       Scenario  Year  Country Region               Area  \
# 0          SC1  2030  DENMARK    DK1          DK1_Large
# 1          SC1  2030  DENMARK    DK1          DK1_Large
# 2          SC1  2030  DENMARK    DK1          DK1_Large
# 3          SC1  2030  DENMARK    DK1          DK1_Large
# 4          SC1  2030  DENMARK    DK1          DK1_Large
# ...        ...   ...      ...    ...                ...
# 17586      SC3  2050   CYPRUS     CY     CY_IDVU-HOTWTR
# 17587      SC3  2050   CYPRUS     CY     CY_IDVU-HOTWTR
# 17588      SC3  2050   CYPRUS     CY     CY_IDVU-HOTWTR
# 17589      SC3  2050   CYPRUS     CY     CY_IDVU-HOTWTR
# 17590      SC3  2050   CYPRUS     CY  CY_IDVU-SPACEHEAT
#
#                                            Generation      Fuel Commodity  \
# 0                                   GNR_BO_BIOIL_E-79    BIOOIL      HEAT
# 1                                   GNR_BO_BIOIL_E-79    BIOOIL      HEAT
# 2                                   GNR_BO_BIOIL_E-85    BIOOIL      HEAT
# 3                                   GNR_BO_BIOIL_E-85    BIOOIL      HEAT
# 4                                   GNR_BO_BIOIL_E-93    BIOOIL      HEAT
# ...                                               ...       ...       ...
# 17586             GNR_HP_ELEC_AIR-WTR_COP-325_SS-4-KW  ELECTRIC      HEAT
# 17587  GNR_HP_ELEC_GROUND-WTR_COP-400_SS-10-KW_Y-2050  ELECTRIC      HEAT
# 17588             GNR_HS_HEAT_WTR-TANK_SS_E-95_Y-2010      HEAT      HEAT
# 17589             GNR_HS_HEAT_WTR-TANK_SS_E-95_Y-2010      HEAT      HEAT
# 17590      GNR_HP_ELEC_AIR-AIR_COP-360_SS-4-KW_Y-2050  ELECTRIC      HEAT
#
#                        Technology         Category Unit     Value
# 0                         BOILERS        EXOGENOUS   GW  0.005500
# 1                         BOILERS  DECOMMISSIONING   GW -0.005500
# 2                         BOILERS        EXOGENOUS   GW  0.109900
# 3                         BOILERS  DECOMMISSIONING   GW -0.109900
# 4                         BOILERS        EXOGENOUS   GW  0.023200
# ...                           ...              ...  ...       ...
# 17586               ELECT-TO-HEAT  DECOMMISSIONING   GW -0.004744
# 17587               ELECT-TO-HEAT       ENDOGENOUS   GW  0.246230
# 17588  INTRASEASONAL-HEAT-STORAGE        EXOGENOUS   GW  1.861753
# 17589  INTRASEASONAL-HEAT-STORAGE  DECOMMISSIONING   GW -1.861753
# 17590               ELECT-TO-HEAT       ENDOGENOUS   GW  0.387330
#
# [17591 rows x 12 columns]

# %%
### 1.1.3 Plotting bar charts with an interactive gui
res.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# VBox(children=(HBox(children=(Box(children=(Text(value='', description='Title:'), FloatSlider(value=12.0, desc…
# Output()
# HBox()
# Output()
# VBox(children=(HBox(children=(Box(children=(Button(description='Plot', icon='check', style=ButtonStyle(), tool…
# Output()
# Output()

# %%
### 1.1.4 Plotting production profiles
fig, ax = res.plot_profile(scenario='SC1', year=2050, commodity='Electricity', columns='Technology',
                 region='DK1')

# %%
### 1.1.5 Plotting map of transmission capacity
fig, ax = res.plot_map(scenario='SC3', year=2050, commodity='Electricity', lines='Capacity', generation='Capacity')
# Out:
# Found MainResults in files\MainResults_Example3.gdx
# background set to "None"
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:354: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:354: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:354: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:664: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %% [markdown]
# ### Other General Functions

# %%
### Using symbol_to_df
import gams
import os
ws = gams.GamsWorkspace()
db = ws.add_database_from_gdx(os.path.abspath('files/MainResults_Example1.gdx'))

fuel = symbol_to_df(db, 'F_CONS_YCRA')
fuel
# Out:
# C:\Users\s233235\AppData\Local\Temp\ipykernel_26048\761078643.py:4: UserWarning: The GAMS version (47.6.0) differs from the API version (48.4.0).
#   ws = gams.GamsWorkspace()
#      Year  Country Region                         Area  \
# 0    2030  DENMARK    DK1                    DK1_Large
# 1    2030  DENMARK    DK1                    DK1_Large
# 2    2030  DENMARK    DK1                    DK1_Large
# 3    2030  DENMARK    DK1                    DK1_Large
# 4    2030  DENMARK    DK1                    DK1_Large
# ..    ...      ...    ...                          ...
# 186  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG1
# 187  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG2
# 188  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG2
# 189  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG3
# 190  2050  DENMARK    DK2  DK2_VRE-ONS_SP277-HH100_RG3
#
#                                  Generation       Fuel         Technology  \
# 0     GNR_BO_MSW_E-106_LS-35-MW-FEED_Y-2030  MUNIWASTE            BOILERS
# 1                      GNR_ENG_BGAS_BP_E-36     BIOGAS  CHP-BACK-PRESSURE
# 2                      GNR_ENG_BGAS_BP_E-39     BIOGAS  CHP-BACK-PRESSURE
# 3                      GNR_ENG_BGAS_BP_E-40     BIOGAS  CHP-BACK-PRESSURE
# 4                      GNR_ENG_BGAS_BP_E-41     BIOGAS  CHP-BACK-PRESSURE
# ..                                      ...        ...                ...
# 186  GNR_WT-SP277-HH100_ONS_LS_L-RG1_Y-2030       WIND            WIND-ON
# 187  GNR_WT-SP277-HH100_ONS_LS_L-RG2_Y-2030       WIND            WIND-ON
# 188  GNR_WT-SP277-HH100_ONS_LS_L-RG2_Y-2050       WIND            WIND-ON
# 189  GNR_WT-SP277-HH100_ONS_LS_L-RG3_Y-2030       WIND            WIND-ON
# 190  GNR_WT-SP277-HH100_ONS_LS_L-RG3_Y-2050       WIND            WIND-ON
#
#     Unit         Value
# 0    TWh -8.299139e-17
# 1    TWh  1.611000e-03
# 2    TWh  4.791692e-03
# 3    TWh  6.390300e-04
# 4    TWh  2.584585e-03
# ..   ...           ...
# 186  TWh  7.214518e-01
# 187  TWh  2.082185e+00
# 188  TWh  5.335354e-01
# 189  TWh  2.618147e+00
# 190  TWh  2.866557e-01
#
# [191 rows x 9 columns]
