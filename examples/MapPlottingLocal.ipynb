# %% [markdown]
# # Pybalmorel for map plotting
#
# This notebook provide examples on how to use the pybalmorel post processing map plotting tool.

# %%
### 0.1 Use development scripts or the package installed from pip
use_development = True
if use_development:
    import sys
    import os
    # Adjust the sys.path to include the project root directory
    project_root = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..'))
    if project_root not in sys.path:
        sys.path.insert(0, project_root)
    from src.pybalmorel import MainResults
    from src.pybalmorel.utils import symbol_to_df
else:
    from pybalmorel import MainResults
    from pybalmorel.utils import symbol_to_df

# %%
### 0.2 Loading several scenarios
res = MainResults(files=['MainResults_EU_2050.gdx', 'MainResults_EU_2050_NoH2.gdx'], paths='files', scenario_names=['BASE', 'NOH2'])
# Out:
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_EU_2050.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\examples\files\MainResults_EU_2050_NoH2.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\classes.py:103: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = gams.GamsWorkspace()

# %%
fig, ax = res.plot_map(scenario='BASE', year=2050, commodity='Hydrogen', lines='Capacity', generation='Capacity')
# Out:
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# Found MainResults in files\MainResults_EU_2050.gdx
# ...

# %%
fig, ax = res.plot_map(scenario='NOH2', year=2050, commodity='Hydrogen', lines='Capacity', generation='Capacity')
# Out:
# Found MainResults in files\MainResults_EU_2050_NoH2.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# ...

# %%
fig, ax = res.plot_map(scenario='BASE', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production')
# Out:
# Found MainResults in files\MainResults_EU_2050.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# ...

# %%
fig, ax = res.plot_map(scenario='NOH2', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production')
# Out:
# Found MainResults in files\MainResults_EU_2050_NoH2.gdx
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# c:\Users\s233235\Documents\Pybalmorel\pybalmorel\src\pybalmorel\plotting\maps_balmorel.py:399: UserWarning: The GAMS version (48.6.1) differs from the API version (48.4.0).
#   ws = GamsWorkspace(os.getcwd())
# ...
